# %%
import yorkpy
import yorkpy.analytics as yka
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy'

# %%
os.chdir('CSV_Dtsets/IPL/IPLT20-Matches')

# %%
os.listdir()[-1]
# Out:
# 'Sunrisers Hyderabad-Royal Challengers Bangalore-2019-03-31.csv'

# %%
srhrcb= pd.read_csv('Sunrisers Hyderabad-Royal Challengers Bangalore-2019-03-31.csv')
srhrcb.head()
# Out:
#    delivery      batsman  bowler extras_dict  non_striker  \
# 0       0.1  JM Bairstow  MM Ali           0    DA Warner
# 1       0.2  JM Bairstow  MM Ali           0    DA Warner
# 2       0.3  JM Bairstow  MM Ali           0    DA Warner
# 3       0.4    DA Warner  MM Ali           0  JM Bairstow
# 4       0.5    DA Warner  MM Ali           0  JM Bairstow
#
#                                  runs_dict wicket_dict  wides  noballs  \
# 0  {'extras': 0, 'total': 0, 'batsman': 0}           0    0.0      0.0
# 1  {'extras': 0, 'total': 4, 'batsman': 4}           0    0.0      0.0
# 2  {'extras': 0, 'total': 1, 'batsman': 1}           0    0.0      0.0
# 3  {'extras': 0, 'total': 4, 'batsman': 4}           0    0.0      0.0
# 4  {'extras': 0, 'total': 1, 'batsman': 1}           0    0.0      0.0
#
#    legbyes  ...  resultHow  resultTeam non_boundary   ManOfMatch overs  \
# 0      0.0  ...          0           0            0  JM Bairstow    20
# ...

# %%
match= srhrcb
theTeam= srhrcb.team1
opposition= srhrcb.team2

# %%
yka.getRunsConceded(srhrcb)
# Out:
# bowler
# B Kumar            25
# C de Grandhomme    16
# MM Ali             29
# Mohammad Nabi      11
# Mohammed Siraj     38
# P Ray Barman       56
# Rashid Khan        25
# S Kaul             16
# Sandeep Sharma     19
# UT Yadav           47
# V Shankar          13
# YS Chahal          44
# Name: runs, dtype: int32

# %%
np.sum(yka.getRunsConceded(srhrcb))
# Out:
# 339

# %%
yka.getOvers(srhrcb)
# Out:
#                  overs
# bowler
# B Kumar              3
# C de Grandhomme      1
# MM Ali               3
# Mohammad Nabi        4
# Mohammed Siraj       4
# P Ray Barman         4
# Rashid Khan          4
# S Kaul               3
# Sandeep Sharma       3
# UT Yadav             4
# V Shankar            2
# YS Chahal            4

# %%
yka.getMaidens(srhrcb)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:573: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['over']=df1.delivery.astype(int)
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['runsConceded']=df1['runs'] + df1['wides'] + df1['noballs']
#                  maiden
# bowler
# B Kumar             0.0
# C de Grandhomme     0.0
# MM Ali              0.0
# Mohammad Nabi       0.0
# ...

# %%
yka.getWickets(srhrcb)
# Out:
#                 player_out
# bowler
# Mohammad Nabi            4
# Mohammed Siraj           1
# Rashid Khan              1
# Sandeep Sharma           4
# V Shankar                1
# YS Chahal                1

# %%
yka.teamBowlingScorecardMatch(srhrcb, srhrcb.team1)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:573: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['over']=df1.delivery.astype(int)
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:576: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['runsConceded']=df1['runs'] + df1['wides'] + df1['noballs']
#             bowler  overs  runs  maidens  wicket   econrate
# 0  C de Grandhomme      1    16        0       0  16.000000
# ...

# %%
yka.teamBowlingScorecardMatch(srhrcb, srhrcb.team2)
# Out:
#            bowler  overs  runs  maidens  wicket  econrate
# 0         B Kumar      3    25        0       0  8.333333
# 1   Mohammad Nabi      4    11        0       4  2.750000
# 2     Rashid Khan      4    25        0       1  6.250000
# 3          S Kaul      3    16        0       0  5.333333
# 4  Sandeep Sharma      3    19        0       4  6.333333
# 5       V Shankar      2    13        0       1  6.500000

# %%
 yka.teamBowlingWicketMatch(match,theTeam,opposition, plot=False)
# Out:
#            bowler   player_out  kind
# 0  Mohammed Siraj    V Shankar     1
# 1       YS Chahal  JM Bairstow     1

# %%
 yka.teamBowlingWicketKindMatch(match,theTeam,opposition, plot=False)
# Out:
#            bowler     kind  player_out
# 0  Mohammed Siraj  run out           1
# 1       YS Chahal   caught           1

# %%
 yka.teamBowlingWicketMatch(match,opposition, theTeam, plot=False)
# Out:
#            bowler       player_out  kind
# 0   Mohammad Nabi   AB de Villiers     1
# 1   Mohammad Nabi         PA Patel     1
# 2   Mohammad Nabi           S Dube     1
# 3   Mohammad Nabi       SO Hetmyer     1
# 4     Rashid Khan         UT Yadav     1
# 5  Sandeep Sharma           MM Ali     1
# 6  Sandeep Sharma     P Ray Barman     1
# 7  Sandeep Sharma          V Kohli     1
# 8  Sandeep Sharma        YS Chahal     1
# 9       V Shankar  C de Grandhomme     1

# %%
 yka.teamBowlingWicketKindMatch(match,opposition, theTeam, plot=False)
# Out:
#            bowler     kind  player_out
# 0   Mohammad Nabi   bowled           1
# 1   Mohammad Nabi   caught           2
# 2   Mohammad Nabi  stumped           1
# 3     Rashid Khan  run out           1
# 4  Sandeep Sharma   caught           3
# 5  Sandeep Sharma  run out           1
# 6       V Shankar  run out           1

# %%
yka.matchWormChart(match, theTeam, opposition, plot=True, savePic=False)
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:1200: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['cumsum']=df3.total.cumsum()
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:1202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['cumsum'] = df4.total.cumsum()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
