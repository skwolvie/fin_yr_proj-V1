# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# !pip install yorkpy

# %%
import pandas as pd
import numpy as np

# %%
import os
import yaml
import json

# %%
import yorkpy
import yorkpy.analytics as yka

# %% [markdown]
# # CONVERTING ALL YAML IPL & INTL-T20 MATCHES FILES TO CSV

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy'

# %%
os.chdir('YAML_Dtsets//INTLT20_YAML_Files')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\YAML_Dtsets\\INTLT20_YAML_Files'

# %%
yka.convertAllYaml2PandasDataframesT20(".","../../CSV_Dtsets/IntlT20/IntlT20-Matches")
# Out:
# File no= 0
# Converting file: 1001349.yaml
# C:\Users\sachi\anaconda3\lib\site-packages\yorkpy\analytics.py:76: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   a=yaml.load(f)
# Team1:diff: ['penalty']
# team1: penalty
# Team2:diff: ['noballs', 'penalty']
# team2: noballs
# team2: penalty
# Team1-missing columns: []
# Team2-missing columns: []
# Length of info field= 10
# Wintype= wickets
# Win value= wickets
# win margin= 5
# ../../CSV_Dtsets/IntlT20/IntlT20-Matches\Australia-Sri Lanka-2017-02-17.csv
# Dataframe shape= (250, 38)
#
#
# File no= 1
# Converting file: 1001351.yaml
# Team1:diff: ['noballs', 'penalty', 'byes']
# team1: noballs
# team1: penalty
# team1: byes
# Team2:diff: ['noballs', 'penalty', 'byes']
# team2: noballs
# team2: penalty
# team2: byes
# Team1-missing columns: []
# Team2-missing columns: []
# Length of info field= 11
# Wintype= wickets
# ...

# %%
os.chdir('../..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy'

# %%
os.chdir('YAML_Dtsets//IPLT20_YAML_Files')

# %%
yka.convertAllYaml2PandasDataframesT20(".","../../CSV_Dtsets/IPL/IPLT20-Matches")
# Out:
# File no= 0
#
#
# File no= 1
# Converting file: 1082591.yaml
# Team1:diff: ['penalty', 'byes']
# team1: penalty
# team1: byes
# Team2:diff: ['penalty', 'byes']
# team2: penalty
# team2: byes
# Team1-missing columns: []
# Team2-missing columns: []
# Length of info field= 12
# Wintype= runs
# Win value= runs
# win margin= 35
# ../../CSV_Dtsets/IPL/IPLT20-Matches\Sunrisers Hyderabad-Royal Challengers Bangalore-2017-04-05.csv
# Dataframe shape= (248, 38)
#
#
# File no= 2
# Converting file: 1082592.yaml
# Team1:diff: ['noballs', 'penalty']
# team1: noballs
# team1: penalty
# Team2:diff: ['noballs', 'penalty', 'byes']
# team2: noballs
# team2: penalty
# team2: byes
# Team1-missing columns: []
# Team2-missing columns: []
# Length of info field= 12
# Wintype= wickets
# Win value= wickets
# win margin= 7
# ../../CSV_Dtsets/IPL/IPLT20-Matches\Rising Pune Supergiant-Mumbai Indians-2017-04-06.csv
# Dataframe shape= (247, 38)
#
#
# File no= 3
# Converting file: 1082593.yaml
# ...

# %% [markdown]
# # EXTRACTING ALL MATCHES B/W 2 TEAMS & ALL MATCHES B/W ALL OPPOSITION OF BOTH IPL & INTL-T20

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\YAML_Dtsets\\IPLT20_YAML_Files'

# %%
os.chdir('../..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy'

# %%
os.chdir('CSV_Dtsets/IPL/IPLT20-Matches')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\CSV_Dtsets\\IPL\\IPLT20-Matches'

# %%
yka.saveAllMatchesBetween2IPLTeams(".","../IPLT20-allMatchesBetween2Teams")
# Out:
# Team1= Chennai Super Kings team2= Deccan Chargers
# 10
# Team1= Chennai Super Kings team2= Delhi Daredevils
# 18
# Team1= Chennai Super Kings team2= Kings XI Punjab
# 21
# Team1= Chennai Super Kings team2= Kochi Tuskers Kerala
# 2
# Team1= Chennai Super Kings team2= Kolkata Knight Riders
# 20
# Team1= Chennai Super Kings team2= Mumbai Indians
# 28
# Team1= Chennai Super Kings team2= Pune Warriors
# 6
# Team1= Chennai Super Kings team2= Rajasthan Royals
# 21
# Team1= Chennai Super Kings team2= Royal Challengers Bangalore
# 23
# Team1= Chennai Super Kings team2= Sunrisers Hyderabad
# 12
# Team1= Chennai Super Kings team2= Gujarat Lions
# 0
# Team1= Chennai Super Kings team2= Rising Pune Supergiants
# 0
# Team1= Deccan Chargers team2= Chennai Super Kings
# 10
# Team1= Deccan Chargers team2= Delhi Daredevils
# 11
# Team1= Deccan Chargers team2= Kings XI Punjab
# 10
# Team1= Deccan Chargers team2= Kochi Tuskers Kerala
# 1
# Team1= Deccan Chargers team2= Kolkata Knight Riders
# 9
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\CSV_Dtsets\\IPL\\IPLT20-Matches'

# %%
yka.saveAllMatchesAllOppositionIPLT20(".","../IPLT20-allMatchesAllOpposition")
# Out:
# Team= Chennai Super Kings
# 164
# Team= Deccan Chargers
# 75
# Team= Delhi Daredevils
# 161
# Team= Kings XI Punjab
# 176
# Team= Kochi Tuskers Kerala
# 14
# Team= Kolkata Knight Riders
# 178
# Team= Mumbai Indians
# 187
# Team= Pune Warriors
# 46
# Team= Rajasthan Royals
# 147
# Team= Royal Challengers Bangalore
# 180
# Team= Sunrisers Hyderabad
# 108
# Team= Gujarat Lions
# 30
# Team= Rising Pune Supergiants
# 14

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\CSV_Dtsets\\IPL\\IPLT20-Matches'

# %%
os.chdir('../..')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\CSV_Dtsets'

# %%
os.chdir('IntlT20/IntlT20-Matches')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sachi\\Desktop\\YorkPy\\CSV_Dtsets\\IntlT20\\IntlT20-Matches'

# %%
yka.saveAllMatchesBetween2IntlT20s(".","../IntlT20-allMatchesBetween2Teams")
# Out:
# Team1= Afghanistan team2= Australia
# 0
# Team1= Afghanistan team2= Bangladesh
# 3
# Team1= Afghanistan team2= Bermuda
# 0
# Team1= Afghanistan team2= Canada
# 1
# Team1= Afghanistan team2= England
# 2
# Team1= Afghanistan team2= Hong Kong
# 4
# Team1= Afghanistan team2= India
# 2
# Team1= Afghanistan team2= Ireland
# 10
# Team1= Afghanistan team2= Kenya
# 3
# Team1= Afghanistan team2= Nepal
# 1
# Team1= Afghanistan team2= Netherlands
# 4
# Team1= Afghanistan team2= New Zealand
# 0
# Team1= Afghanistan team2= Oman
# 4
# Team1= Afghanistan team2= Pakistan
# 1
# Team1= Afghanistan team2= Scotland
# 5
# Team1= Afghanistan team2= South Africa
# 2
# Team1= Afghanistan team2= Sri Lanka
# 1
# Team1= Afghanistan team2= United Arab Emirates
# 6
# Team1= Afghanistan team2= West Indies
# 7
# Team1= Afghanistan team2= Zimbabwe
# 7
# Team1= Australia team2= Afghanistan
# 0
# Team1= Australia team2= Bangladesh
# 4
# Team1= Australia team2= Bermuda
# 0
# Team1= Australia team2= Canada
# 0
# ...

# %%
yka.saveAllMatchesAllOppositionIntlT20(".","../IntlT20-allMatchesAllOpposition")
# Out:
# Team= Afghanistan
# 64
# Team= Australia
# 103
# Team= Bangladesh
# 72
# Team= Bermuda
# 12
# Team= Canada
# 21
# Team= England
# 107
# Team= Hong Kong
# 42
# Team= India
# 100
# Team= Ireland
# 70
# Team= Kenya
# 28
# Team= Nepal
# 27
# Team= Netherlands
# 56
# Team= New Zealand
# 110
# Team= Oman
# 28
# Team= Pakistan
# 122
# Team= Scotland
# 40
# Team= South Africa
# 110
# Team= Sri Lanka
# 109
# Team= United Arab Emirates
# 40
# Team= West Indies
# 107
# Team= Zimbabwe
# 61
